# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_48976\2502006577.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("df.csv")
df
# Out:
#                                                  title  \
# 0                              Senior Python Developer
# 1                   Middle Back-end Developer (PYTHON)
# 2                     Senior Backend Engineer - Python
# 3                                     Python developer
# 4                     Python Developer / Data Engineer
# ..                                                 ...
# 200                   Senior Python Developer with AWS
# 201          Python Engineer with AI (Computer Vision)
# 202                             Senior Python Engineer
# 203  Python developer with Cloud and DevOps experience
# 204                            Senior Python Developer
#
#                                           technologies             english  \
# 0                      Python,FastApi,Git,AWS,Jira,OOP  Upper-Intermediate
# 1    Python,Django,Redis,SQL,Git,Docker,Django Rest...        Intermediate
# 2                          Python,Redis,AWS,Kubernetes  Upper-Intermediate
# 3    Python,Django,Redis,Flask,SQL,Git,AWS,Jira,HTM...        Intermediate
# 4    Python,Redis,PostgreSQL,Flask,SQL,REST Api,Doc...  Upper-Intermediate
# ..                                                 ...                 ...
# 200                    Python,PostgreSQL,SQL,AWS,Linux  Upper-Intermediate
# 201                 Python,Django,Mongo,SQL,Celery,AWS  Upper-Intermediate
# 202  Python,Django,Redis,PostgreSQL,FastApi,SQL,Git...  Upper-Intermediate
# 203         Python,Git,AWS,Docker,OOP,Kubernetes,Linux  Upper-Intermediate
# 204                                 Python,Git,AWS,OOP  Upper-Intermediate
#
#                                              recruiter  \
# 0    djinni.co/r/120107-recruitment-researcher-at-n...
# 1         djinni.co/r/41173-hr-manager-v-factum-group/
# 2      djinni.co/r/121196-co-founder-at-apomsolutions/
# 3    djinni.co/r/29415-chief-product-officer-at-cib...
# 4         djinni.co/r/103039-recruiter-at-globallogic/
# ..                                                 ...
# 200  djinni.co/r/82048-recruitment-researcher-at-lu...
# 201  djinni.co/r/105242-research-consultant-at-adap...
# 202  djinni.co/r/10819-kerivnik-pidboru-ta-adaptats...
# 203  djinni.co/r/82048-recruitment-researcher-at-lu...
# 204  djinni.co/r/82048-recruitment-researcher-at-lu...
#
#                                                    url
# 0    https://djinni.co/jobs/573224-senior-python-de...
# 1    https://djinni.co/jobs/627439-middle-back-end-...
# 2    https://djinni.co/jobs/627342-senior-backend-e...
# 3      https://djinni.co/jobs/553278-python-developer/
# 4    https://djinni.co/jobs/627390-python-developer...
# ..                                                 ...
# 200  https://djinni.co/jobs/615790-senior-python-de...
# 201  https://djinni.co/jobs/605048-python-engineer-...
# 202  https://djinni.co/jobs/611100-senior-python-en...
# 203  https://djinni.co/jobs/611911-python-developer...
# 204  https://djinni.co/jobs/617631-senior-python-de...
#
# [205 rows x 5 columns]

# %%
def plot_top_technologies(data: pd.DataFrame, title: str):
    plt.figure(figsize=(10, 6))
    data.plot(kind="bar", color="green")
    plt.title(title)
    plt.xlabel("Technologies")
    plt.ylabel("Frequency")
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()
    
all_technologies = (
    df["technologies"].str.split(",").explode().value_counts()
)

top_technologies = all_technologies.head(30)

plot_top_technologies(top_technologies, "Top 30 Most Mentioned Technologies")

# %%
english_level = df.groupby("english")["title"].count()

plt.pie(
    english_level.values,
    labels=english_level.index,
    autopct="%1.1f%%",
)
plt.title("Demand for levels of English")
plt.show()
